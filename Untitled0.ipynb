# %% [markdown]
# **Mounting** **from** **Google** **Collab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Create** **a** **Sub**-**Folder** **under** **the** **IS110_BPerformance_Hucalinas**

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Hucalinas/PythonEnvi_Hucalinas/
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Hucalinas/PythonEnvi_Hucalinas

# %% [markdown]
# **Path for Working Directory**

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Hucalinas/PythonEnvi_Hucalinas

# %% [markdown]
# **Create a New Environment**

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 105.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 38.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Naming the Environment**

# %%
# !virtualenv hucalinas
# Out:
# created virtual environment CPython3.12.12.final.0-64 in 6845ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Hucalinas/PythonEnvi_Hucalinas/hucalinas, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %% [markdown]
# **Activating the Environment**

# %%
# !source hucalinas/bin/activate

# %% [markdown]
# **Writing the requirements.txt**

# %%
# %%writefile requirements.Text
# pandas
# numpy
# Out:
# Writing requirements.Text

# %% [markdown]
# **Installing the Package in the requirements.txt**

# %%
# !hucalinas/bin/pip install -r requirements.Text
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 96.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 115.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]
# ...

# %% [markdown]
# **Requirement txt has been Created or Updated**

# %%
# !hucalinas/bin/pip freeze > requirements.txt

# %%
# !hucalinas/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# numpy           2.4.2
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %% [markdown]
# **Incase you need to Add, Write In and Add File and Run Again**

# %%
# !cat requirements.txt
# Out:
# numpy==2.4.2
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0
